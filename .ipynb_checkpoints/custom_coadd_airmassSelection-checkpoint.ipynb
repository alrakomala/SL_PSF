# %%
# From Melissa Graham notebook

# standard python packages for numerical processing, plotting, and databases
import time
import getpass
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas

# astropy package for time unit conversions
from astropy.time import Time

# lsst packages for data access and display
import lsst.geom
import lsst.afw.display as afwDisplay

# import lsst.daf.butler as dafButler
from lsst.daf.butler import Butler, DatasetType, CollectionType

# lsst packages for executing pipeline tasks
from lsst.ctrl.mpexec import SimplePipelineExecutor
from lsst.pipe.base import Pipeline, Instrument

# %% [markdown]
# ### 1.2. Define functions and parameters
#
# Set a few parameters related to plotting and display.

# %%
font = {'size': 14}
matplotlib.rc('font', **font)

pandas.set_option('display.max_rows', 1000)

afwDisplay.setDefaultBackend('matplotlib')

# %%
config = 'dp02'
collection = '2.2i/runs/DP0.2'
butler = Butler(config, collections=collection)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">botocore.credentials</span> <span style="color: var(--jp-info-color0)">INFO</span>: Found credentials in shared credentials file: /home/alrakomala/.lsst/aws-credentials.ini</pre>
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).

# %% [markdown]
# > **Notice:** It is OK to ignore a pink-window message saying "WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01)."

# %% [markdown]
# ## 2. Identify the visits to combine

# %%
# %%time

my_ra_deg = 55.745834
my_dec_deg = -32.269167

my_spherePoint = lsst.geom.SpherePoint(my_ra_deg*lsst.geom.degrees,
                                       my_dec_deg*lsst.geom.degrees)

skymap = butler.get('skyMap')
tract = skymap.findTract(my_spherePoint)
my_tract = tract.tract_id
my_patch = tract.findPatch(my_spherePoint).getSequentialIndex()
print('My tract and patch: ', my_tract, my_patch)

my_dataId = {'band': 'i', 'tract': my_tract, 'patch': my_patch}
my_deepCoadd = butler.get('deepCoadd', dataId=my_dataId)

del my_ra_deg, my_dec_deg, my_spherePoint, tract
# Out:
# My tract and patch:  4431 17
# CPU times: user 3.62 s, sys: 1.3 s, total: 4.91 s
# Wall time: 5.08 s

# %% [markdown]
# Option to display the deepCoadd image.

# %%
fig = plt.figure(figsize=(12, 8))
afw_display = afwDisplay.Display(1)
afw_display.scale('asinh', 'zscale')
afw_display.mtv(my_deepCoadd.image)
plt.gca().axis('off')
# Out:
# (11899.5, 16099.5, 7899.5, 12099.5)

# %% [markdown]
# ### 2.2. Retrieve the deepCoadd's input visits

# %%
# %%time

my_coadd_inputs = butler.get("deepCoadd_calexp.coaddInputs", my_dataId)
# Out:
# CPU times: user 1.88 s, sys: 1.09 s, total: 2.98 s
# Wall time: 2.57 s

# %% [markdown]
# Option to display the coadd inputs as an astropy table.

# %%
#my_coadd_inputs.visits.asAstropy()

# %% [markdown]
# The length of this table, 161, indicates that 161 separate visits contributed to this deepCoadd.

# %%
len(my_coadd_inputs.visits)
# Out:
# 161

# %% [markdown]
# Option to list all of the deepCoadd input visit ids.

# %% [markdown]
# ### 2.3. Identify airmass range for the input visits

# %%
visitTableRef = list(butler.registry.queryDatasets('visitTable'))
visitTable = butler.get(visitTableRef[0])

# %%
visitTable
# Out:
#            visit physical_filter band         ra       decl  skyRotation  \
# visitId
# 178142    178142       g_sim_1.4    g  48.816726 -42.998764    55.305716
# 180090    180090       g_sim_1.4    g  48.268655 -43.554762    52.942898
# 180134    180134       g_sim_1.4    g  49.346433 -43.826917    69.782977
# 180135    180135       g_sim_1.4    g  50.037170 -41.679127    62.769883
# 183780    183780       g_sim_1.4    g  52.358132 -41.499734   358.191446
# ...          ...             ...  ...        ...        ...          ...
# 629034    629034       z_sim_1.4    z  70.888982 -26.095592    73.652190
# 648610    648610       z_sim_1.4    z  72.150526 -26.008101   335.768899
# 691038    691038       z_sim_1.4    z  71.072029 -25.526301    85.644342
# 712115    712115       z_sim_1.4    z  70.571841 -25.587608   126.404264
# 1207302  1207302       z_sim_1.4    z  71.814876 -25.543604   191.608140
#
#             azimuth   altitude  zenithDistance   airmass  expTime  \
# visitId
# 178142   128.492828  65.364165       24.635835  1.097656     30.0
# 180090   134.109077  68.495289       21.504711  1.073027     30.0
# 180134   143.553058  72.147000       17.853000  1.049297     30.0
# 180135   137.300217  73.291392       16.708608  1.043240     30.0
# 183780   120.956971  58.011960       31.988040  1.173574     30.0
# ...             ...        ...             ...       ...      ...
# 629034    95.156511  50.902969       39.097031  1.278896     30.0
# 648610    97.548979  45.435132       44.564868  1.386305     30.0
# 691038   294.754613  79.703652       10.296348  1.014646     30.0
# 712115   265.762347  51.058909       38.941091  1.262612     30.0
# 1207302  269.218406  57.512253       32.487747  1.170912     30.0
#
#                           expMidpt   expMidptMJD                   obsStart  \
# visitId
# 178142  2022-08-26 07:54:20.697800  59817.329406 2022-08-26 07:54:05.697800
# 180090  2022-08-28 08:05:01.699100  59819.336825 2022-08-28 08:04:46.699100
# 180134  2022-08-28 08:35:56.880000  59819.358297 2022-08-28 08:35:41.880000
# 180135  2022-08-28 08:36:40.252900  59819.358799 2022-08-28 08:36:25.252900
# 183780  2022-09-01 07:01:36.729800  59823.292786 2022-09-01 07:01:21.729800
# ...                            ...           ...                        ...
# 629034  2024-07-23 10:22:41.971100  60514.432430 2024-07-23 10:22:26.971100
# 648610  2024-08-20 08:12:21.216000  60542.341912 2024-08-20 08:12:06.216000
# 691038  2024-10-18 08:19:43.324900  60601.347029 2024-10-18 08:19:28.324900
# 712115  2024-11-16 08:37:58.963100  60630.359710 2024-11-16 08:37:43.963100
# 1207302 2026-11-13 08:26:44.265800  61357.351901 2026-11-13 08:26:29.265800
#
#           obsStartMJD
# visitId
# 178142   59817.329233
# 180090   59819.336652
# 180134   59819.358124
# 180135   59819.358626
# 183780   59823.292613
# ...               ...
# 629034   60514.432257
# 648610   60542.341739
# 691038   60601.346856
# 712115   60630.359537
# 1207302  61357.351728
#
# [19840 rows x 15 columns]

# %% [markdown]
# The fact that the id column for both the my_coadd_inputs.vists table and the visitTable is the visit number (visit id) makes it simple to retrieve the MJDs of our coadd input visits.

# %%
#my_coadd_visits_mjds = visitTable.loc[my_coadd_inputs.visits['id']]['expMidptMJD']
my_coadd_visits_airmass = visitTable.loc[my_coadd_inputs.visits['id']]['airmass']

# %%
binsize = np.arange(np.min(my_coadd_visits_airmass), np.max(my_coadd_visits_airmass), 0.005)

# %%
fig, ax = plt.subplots(2, figsize=(10, 8))

ax[0].hist(my_coadd_visits_airmass, bins=40, color='dodgerblue')
ax[0].set_xlabel('airmass')
ax[0].set_ylabel('Number of Visits')

ax[1].hist(my_coadd_visits_airmass, bins=150, color='dodgerblue')
ax[1].set_xlim(1.0,1.05)
ax[1].set_xlabel('airmass')
ax[1].set_ylabel('Number of Visits')
plt.show()

# %% [markdown]
# ### 2.4. Identify input visits to combine into a new Coadd

# %%
min_airmass = np.min(my_coadd_visits_airmass)

Window1_start = min_airmass
Window1_end = 1.006

Window2_start = 1.3
Window2_end = 1.35

fig, ax = plt.subplots(2, figsize=(10, 8))

ax[0].hist(my_coadd_visits_airmass, bins=50, color='dodgerblue')
ax[0].set_xlabel('airmass')
ax[0].set_ylabel('Number of Visits')
ax[0].axvline(Window1_start, ls='dotted', color='firebrick')
ax[0].axvline(Window1_end, ls='dotted', color='firebrick')
ax[0].axvline(Window2_start, ls='dashed', color='darkorange')
ax[0].axvline(Window2_end, ls='dashed', color='darkorange')

ax[1].hist(my_coadd_visits_airmass, bins=150, color='dodgerblue')
ax[1].set_xlabel('airmass')
ax[1].set_ylabel('Number of Visits')
ax[1].set_xlim([Window1_start-0.001, Window2_end + 0.002])
ax[1].axvline(Window1_start, ls='dotted', color='firebrick')
ax[1].axvline(Window1_end, ls='dotted', color='firebrick')
#ax[1].text(Window1_start+1, 7.5, 'Window1', color='firebrick')
ax[1].axvline(Window2_start, ls='dashed', color='darkorange')
ax[1].axvline(Window2_end, ls='dashed', color='darkorange')
#ax[1].text(Window2_start+1, 7.5, 'Window1', color='darkorange')

plt.show()

# %% [markdown]
# ## 3. Create a coadd for the visits in Window1

# %% [markdown]
# Put the list of visits for Window1 into a string, formatted as a tuple, for use in a query later on.
# ("Formatted as a tuple" means within round brackets and separated by commas).

# %%
my_range = np.array((my_coadd_visits_airmass > Window1_start) & 
                    (my_coadd_visits_airmass < Window1_end))
my_visits = my_coadd_inputs.visits[my_range]
my_visits_tupleString = "("+",".join(my_visits['id'].astype(str))+")"
print(my_visits_tupleString)
# Out:
# (192350,256348,256393,713248,1173799,1205981,1209139,1209192)

# %%
# !butler query-collections dp02 --chains=tree u/alrakomala/*
# Out:
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#                               Name                                   Type
# ---------------------------------------------------------------- -----------
# u/alrakomala/coadd_recreation_nb                                 CHAINED
#   u/alrakomala/coadd_recreation_nb/airmassTestWindow1            RUN
#   2.2i/runs/DP0.2                                                CHAINED
#     2.2i/runs/DP0.2/w_2022_22/PREOPS-1209/20220601T202430Z       RUN
#     2.2i/runs/DP0.2/w_2022_22/PREOPS-1209/20220602T165151Z       RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step7/20220501T161443Z    RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_1/20220512T201515Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_10/20220514T021220Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_11/20220514T051259Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_12/20220514T081014Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_13/20220514T110509Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_14/20220514T140812Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_15/20220514T171751Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_16/20220514T201929Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_17/20220514T232440Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_17/20220516T033516Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_18/20220515T023234Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_19/20220515T054618Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_2/20220513T015911Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_20/20220515T144944Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_3/20220513T050000Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_4/20220515T113417Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_5/20220513T110250Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_6/20220513T140400Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_7/20220513T170841Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_8/20220513T201047Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step6_9/20220513T231122Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_52/20220511T193037Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_51/20220511T172849Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_50/20220511T152602Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_49/20220511T224921Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_48/20220511T115326Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_47/20220511T093215Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_46/20220511T072551Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_45/20220511T051607Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_44/20220511T030333Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_43/20220511T010324Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_42/20220510T225220Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_41/20220510T204315Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_40/20220510T182122Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_39/20220510T165619Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_38/20220510T144157Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_37/20220510T122823Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_36/20220510T102009Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_35/20220510T082734Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_34/20220510T062419Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_30/20220511T210005Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_12/20220507T050423Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_1/20220512T001721Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_1/20220503T191629Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_10/20220506T225821Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_11/20220507T020003Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_13/20220507T224408Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_14/20220508T012319Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_15/20220508T042652Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_16/20220508T072602Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_17/20220508T103019Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_18/20220508T124926Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_19/20220508T155145Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_2/20220505T095134Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_2/20220505T200125Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_20/20220508T185905Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_21/20220508T221147Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_22/20220509T011312Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_23/20220509T041228Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_24/20220509T071757Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_25/20220509T102239Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_26/20220509T132805Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_27/20220509T155625Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_28/20220509T180251Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_29/20220509T200842Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_3/20220505T200225Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_31/20220509T234815Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_32/20220510T020028Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_33/20220510T041257Z RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_4/20220505T233000Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_5/20220506T040307Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_6/20220506T080709Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_7/20220506T121157Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_8/20220506T160546Z  RUN
#     2.2i/runs/DP0.2/v23_0_2/PREOPS-905/step5_9/20220506T195012Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_38/20220429T022751Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_1/20220419T041129Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_10/20220429T200139Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_11/20220430T013535Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_12/20220430T070958Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_13/20220422T152623Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_14/20220423T111506Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_15/20220423T171322Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_16/20220423T220848Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_17/20220424T030657Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_18/20220424T081202Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_19/20220424T131819Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_2/20220419T082436Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_20/20220424T182451Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_21/20220425T033108Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_22/20220425T090248Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_23/20220425T143818Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_24/20220425T200112Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_25/20220426T012543Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_26/20220426T070107Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_27/20220426T123155Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_28/20220426T180134Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_29/20220426T233505Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_3/20220419T123328Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_30/20220427T050650Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_31/20220427T103906Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_32/20220427T161652Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_33/20220427T215556Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_34/20220428T033022Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_35/20220428T091545Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_36/20220428T145517Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_37/20220428T203907Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_39/20220429T081628Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_4/20220419T163046Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_40/20220429T135816Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_5/20220419T204203Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_6/20220420T005103Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_7/20220420T173758Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_8/20220420T233604Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step4_9/20220421T052720Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220418T184335Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220418T180525Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220418T172818Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220418T165935Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220418T165845Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_9/20220405T164242Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_9/20220330T170001Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_7/20220330T145650Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_5/20220329T232416Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220410T153911Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220410T130944Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_32/20220407T030512Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_20/20220406T145057Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_20/20220331T124128Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_19/20220331T110357Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_18/20220406T130306Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_18/20220331T084313Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_17/20220406T111701Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_17/20220331T063809Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_16/20220406T095810Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_16/20220331T050027Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_15/20220406T081059Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_15/20220331T025327Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_14/20220406T063431Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_14/20220331T004509Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_13/20220406T045526Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_13/20220330T224603Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_12/20220405T182718Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_12/20220330T204043Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_11/20220330T190852Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_27/20220322T202545Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_4/20220325T122210Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_29/20220325T223049Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_26/20220325T204503Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_25/20220325T190019Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_24/20220325T174013Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_23/20220325T155617Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_22/20220325T141557Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_2/20220325T104104Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_1/20220326T032806Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_8/20220316T205925Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_6/20220318T134046Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_27/20220316T171018Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_1/20220317T233937Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_6/20220316T192214Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_10/20220315T122041Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_8/20220309T160814Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_6/20220309T170243Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_4/20220315T051405Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_4/20220309T042312Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_31/20220314T212509Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_31/20220307T050825Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_30/20220314T194916Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_30/20220306T160359Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_3/20220315T012904Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_3/20220309T040429Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_29/20220314T204515Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_29/20220306T172459Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_28/20220314T185100Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_28/20220306T041600Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_27/20220306T050001Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_26/20220305T162808Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_25/20220305T164554Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_24/20220305T052326Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_23/20220305T044606Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_22/20220304T174139Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_21/20220314T170839Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_21/20220304T163449Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_2/20220308T164354Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_10/20220310T050847Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_1/20220308T153907Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_11/20220220T032646Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_12/20220218T172932Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_13/20220220T142359Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_13/20220302T190942Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_14/20220219T051120Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_15/20220221T015820Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_15/20220302T200340Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_16/20220219T164501Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_16/20220302T210859Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_17/20220220T035232Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_18/20220220T153612Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_19/20220221T031952Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_19/20220302T215536Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_20/20220225T211807Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_20/20220303T145311Z RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_5/20220218T163030Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_7/20220219T040206Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_9/20220219T154502Z  RUN
#     2.2i/runs/DP0.2/v23_0_1/PREOPS-905/step3_9/20220302T181001Z  RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220124T155505Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220123T195452Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220123T001043Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220122T070559Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T234250Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T191925Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T160922Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T103211Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T081743Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T041501Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T031850Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220121T003836Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220120T161430Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220120T012920Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220112T143133Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220112T114604Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220112T084603Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220112T054912Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220112T010001Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T213932Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T175016Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T095828Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T083238Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T071223Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T063729Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T060953Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T054319Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T051546Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T044925Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220111T041856Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220110T231306Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220107T204134Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220107T163916Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220104T111833Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220104T085126Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220103T202705Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220104T062817Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220103T103400Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220103T010607Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220102T153518Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220102T060840Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220101T211007Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220101T102006Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20220101T014359Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211231T121620Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211231T053432Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211230T230823Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211230T164503Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211230T102720Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211230T042014Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211224T153913Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211224T102944Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211224T053402Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211223T204234Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211223T030157Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211222T182615Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211222T122903Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211222T050757Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211222T004329Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211221T170207Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211221T162728Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211221T021010Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211220T214212Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211220T180923Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211220T040027Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211220T000005Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211219T205411Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211219T150249Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211219T033213Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211218T214417Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211218T144437Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211218T041605Z      RUN
#     2.2i/runs/DP0.2/v23_0_0_rc5/PREOPS-905/20211218T002844Z      RUN
#     2.2i/raw/DR6/WFD                                             TAGGED
#     2.2i/calib/DM-30694                                          CALIBRATION
#     2.2i/calib/gen2                                              CALIBRATION
#     2.2i/calib/DM-30694/unbounded                                RUN
#     skymaps                                                      RUN
#     refcats/PREOPS-301                                           RUN
#     2.2i/truth_summary                                           RUN
# u/alrakomala/coadd_recreation_nb/TestWindow1                     RUN
# u/alrakomala/coadd_recreation_nb/airmassTestWindow1              RUN

# %% [markdown]
# ### 3.1. Name a new butler collection for your output
#
# > **Important:** Use the convention `u/[Your User Name]/coadd_recreation_nb` to set up a new output collection for this tutorial.
# Recall that RSP user names are the same as GitHub user names, because GitHub accounts are used to authorize access to the RSP.

# %%
my_username = getpass.getuser()
my_outputCollection = 'u/'+my_username+'/coadd_recreation_nb'
#my_outputCollection = 'u/'+my_username+'/output_testKA'
print('Name of new butler collection for my output: ', my_outputCollection)
# Out:
# Name of new butler collection for my output:  u/alrakomala/coadd_recreation_nb

# %% [markdown]
# Check if this output collection already exists? If nothing is printed below this cell, the output collection does not already exist.

# %%
for c in sorted(butler.registry.queryCollections()):
    if c.find(my_outputCollection) > -1:
        print(c)
# Out:
# u/alrakomala/coadd_recreation_nb
# u/alrakomala/coadd_recreation_nb/TestWindow1

# %% [markdown]
# Delete the current butler. In the next section, a simple butler is created and used thereafter.

# %%
del butler

# %% [markdown]
# ### 3.2. Set up a simple butler and name the output run for Window1

# %% [markdown]
# > **Notice:** In future updates to the LSST Science Pipelines, it will be possible to use: <br>
# `simpleButler = SimplePipelineExecutor.prep_butler(config, inputs=[collection], output=my_outputCollection)`
#
# For the LSST Science Pipelines version Weekly_2022_22, the following workaround is needed to set up a simple butler and create a new output collection with the name selected above.
#
# Users have the option of defining the name of the `outputRun` to be whatever they want.
#
# For example, to name an `outputRun` using a unique timestamp, use: <br>
# `outputRun = f"{my_outputCollection}/{Instrument.makeCollectionTimestamp()}"` <br>
# Timestamps are year month day T hour minute second Z, where the time is UTC.
#
# But in this case, we will just use `TestWindow1` as our `outputRun` name.

# %%
#outputRun = f"{my_outputCollection}/TestWindow1"
outputRun = f"{my_outputCollection}/airmassTestWindow1"

tmpButler = Butler(config, writeable=True)

tmpButler.registry.registerCollection(outputRun, CollectionType.RUN)
print('Made CollectionType.RUN: ', outputRun)

tmpButler.registry.registerCollection(my_outputCollection, CollectionType.CHAINED)
print('Made CollectionType.CHAINED: ', my_outputCollection)

collections = [collection]
collections.insert(0, outputRun)

tmpButler.registry.setCollectionChain(my_outputCollection, collections)

simpleButler = Butler(butler=tmpButler, collections=[my_outputCollection], run=outputRun)

del tmpButler
# Out:
# Made CollectionType.RUN:  u/alrakomala/coadd_recreation_nb/airmassTestWindow1
# Made CollectionType.CHAINED:  u/alrakomala/coadd_recreation_nb

# %% [markdown]
# Check that the subdirectory of the newly created output collection is first in the list.
# The output will go into that specific RUN collection.

# %%
simpleButler.registry.getCollectionChain(my_outputCollection)
# Out:
# CollectionSearch(('u/alrakomala/coadd_recreation_nb/airmassTestWindow1', '2.2i/runs/DP0.2'))

# %% [markdown]
# Option: check the output collection run names that currently exist.

# %%
for c in sorted(simpleButler.registry.queryCollections()):
    if c.find(my_outputCollection) > -1:
        print('Found: ', c)
# Out:
# Found:  u/alrakomala/coadd_recreation_nb
# Found:  u/alrakomala/coadd_recreation_nb/TestWindow1
# Found:  u/alrakomala/coadd_recreation_nb/airmassTestWindow1

# %% [markdown]
# ### 3.3. Select the makeWarp and assembleCoadd tasks

# %%
assembleCoaddPipeline = Pipeline.from_uri('${PIPE_TASKS_DIR}/pipelines/DRP.yaml#makeWarp,assembleCoadd')

# %% [markdown]
# ### 3.4. Configure the pipeline
#
# Configurations can be set using `addConfigOverride(<taskName>, <configName>, <configValue>)`.
#
# There is only one configuration that must be set, and it is to clarify to the pipeline that it _does not_ need to redo a final image characterization step.
# Currently, this configuration is needed due to a version mismatch: the DP0.2 data sets were processed with Version 23 of the LSST Science Pipelines, whereas this notebook uses the version "Weekly 2022_22".
# This configuration might not be needed in the future.

# %%
assembleCoaddPipeline.addConfigOverride('makeWarp', 'doApplyFinalizedPsf', False)

# %% [markdown]
# ### 3.5. Create the full query string
#
# Above, the visits to be recombined were stored in "my_visits_tupleString".
#
# Below, the full query string is built to include the patch being recreated.

# %%
queryString = f"tract = {my_tract} AND patch = {my_patch} AND " + \
              f"visit in {my_visits_tupleString} AND skymap = 'DC2'"

print(queryString)
# Out:
# tract = 4431 AND patch = 17 AND visit in (192350,256348,256393,713248,1173799,1205981,1209139,1209192) AND skymap = 'DC2'

# %% [markdown]
# ### 3.6. Use the Simple Pipeline Executor to run the pipeline

# %%
# %%time
spe = SimplePipelineExecutor.from_pipeline(assembleCoaddPipeline, where=queryString, butler=simpleButler)
# Out:
# CPU times: user 1.39 s, sys: 151 ms, total: 1.54 s
# Wall time: 1min 58s

# %% [markdown]
# Run the pipeline.
#
# There will be a lot of standard output. Right-click to the left of the cell and choose "Enable Scrolling for Outputs" to condense all of the output into a scrollable inset window.
#
# This takes about 16 minutes for 6 visits.

# %%
# %%time
quanta = spe.run()
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 176, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 179, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 183, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 186, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 1 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 176, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (55, 55)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 2 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 179, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (55, 55)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 3 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 183, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (55, 55)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 4 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 186, visit: 1209192, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (55, 55)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: directWarp has 15761371 good pixels (89.4%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: psfMatchedWarp has 15516248 good pixels (88.0%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeWarp&#x27; on quantum {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1209192, ...} took 146.866 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Log records could not be stored in this butler because the datastore can not ingest files, empty record list is stored instead.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 39, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 40, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 42, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 43, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 1 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 39, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (57, 57)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 2 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 40, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (57, 57)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 3 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 42, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (57, 57)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 4 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 43, visit: 1205981, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (57, 57)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: directWarp has 16054633 good pixels (91.0%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: psfMatchedWarp has 15827687 good pixels (89.7%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeWarp&#x27; on quantum {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1205981, ...} took 157.746 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Log records could not be stored in this butler because the datastore can not ingest files, empty record list is stored instead.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 185, visit: 713248, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 188, visit: 713248, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 1 of 2 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 185, visit: 713248, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (43, 43)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 2 of 2 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 188, visit: 713248, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (43, 43)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: directWarp has 11149509 good pixels (63.2%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: psfMatchedWarp has 11050601 good pixels (62.6%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeWarp&#x27; on quantum {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 713248, ...} took 59.680 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Log records could not be stored in this butler because the datastore can not ingest files, empty record list is stored instead.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 10, visit: 1209139, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 11, visit: 1209139, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 1 of 2 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 10, visit: 1209139, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (55, 55)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 2 of 2 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 11, visit: 1209139, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (55, 55)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: directWarp has 3680495 good pixels (20.9%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: psfMatchedWarp has 3603941 good pixels (20.4%)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeWarp&#x27; on quantum {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1209139, ...} took 52.670 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Log records could not be stored in this butler because the datastore can not ingest files, empty record list is stored instead.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 40, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 41, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 43, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.select</span> <span style="color: var(--jp-info-color0)">INFO</span>: Selecting calexp {instrument: &#x27;LSSTCam-imSim&#x27;, detector: 44, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 1 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 40, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (51, 51)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 2 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 41, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (9, 9) to (51, 51)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp.warpAndPsfMatch.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makeWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing calexp 3 of 4 for this Warp: id={instrument: &#x27;LSSTCam-imSim&#x27;, detector: 43, visit: 256393, ...}</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# ...
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Found 8 deepCoadd_directWarp</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 192350, ...} = 1.006</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 256348, ...} = 16.081</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 256393, ...} = 7.305</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 713248, ...} = 0.011</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1173799, ...} = 0.974</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1205981, ...} = 6.320</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1209139, ...} = 0.196</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Weight of deepCoadd_psfMatchedWarp {instrument: &#x27;LSSTCam-imSim&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17, visit: 1209192, ...} = 0.162</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Found 8 deepCoadd_psfMatchedWarp</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling 8 deepCoadd_psfMatchedWarp</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: Creating psf model for interpolation from fwhm(pixels) = 3.0 [default]</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: fallbackValueType MEDIAN has been set to 0.0130</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.assembleStaticSkyModel.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolated over 0 NO_DATA pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detectTemplate</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 6269 positive peaks in 4021 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.007410</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 36 positive peaks in 13 footprints and 3 negative peaks in 2 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.209036</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 8 positive peaks in 6 footprints and 19 negative peaks in 11 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.151977</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 9 positive peaks in 8 footprints and 12 negative peaks in 8 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.010238</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 95 positive peaks in 7 footprints and 24 negative peaks in 6 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.044797</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 157 positive peaks in 21 footprints and 3 negative peaks in 3 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.176346</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 3 positive peaks in 3 footprints and 6 negative peaks in 2 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 0.697937</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 16 positive peaks in 4 footprints and 7 negative peaks in 2 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 0.700730</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 210 positive peaks in 13 footprints and 25 negative peaks in 11 footprints to 5 sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling 8 deepCoadd_directWarp</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: Creating psf model for interpolation from fwhm(pixels) = 3.0 [default]</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: fallbackValueType MEDIAN has been set to 0.0130</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleCoadd.interpImage</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolated over 88 NO_DATA pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;assembleCoadd&#x27; on quantum {band: &#x27;i&#x27;, skymap: &#x27;DC2&#x27;, tract: 4431, patch: 17} took 285.099 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ctrl.mpexec.singleQuantumExecutor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Log records could not be stored in this butler because the datastore can not ingest files, empty record list is stored instead.</pre>
# CPU times: user 17min 49s, sys: 1min 39s, total: 19min 28s
# Wall time: 19min 14s

# %% [markdown]
# ## 4. Display and analyse the results
#
# ### 4.1. The quanta
#
# The "quanta" that was just created is a list of objects corresponding to each of the pipeline tasks that were ran.
# There will be one for each visit’s makeWarp and one for assembleCoadd.
# Each of those has information about, e.g., the name of the task, the reference to the input and output.

# %%
for q, quantum in enumerate(quanta):
    print(q, quantum.taskName)
# Out:
# 0 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 1 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 2 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 3 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 4 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 5 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 6 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 7 lsst.pipe.tasks.makeCoaddTempExp.MakeWarpTask
# 8 lsst.pipe.tasks.assembleCoadd.CompareWarpAssembleCoaddTask

# %% [markdown]
# Set `coadd_index` equal to the index for the outputs of `lsst.pipe.tasks.assembleCoadd`.
#
# When this tutorial was prepared, the output of the cell above showed that the first six elements of quanta (indices 0 through 5) were the results of makeWarp for the six visits, and then the seventh (index 6) was the results of `assembleCoadd`.
#
# This should be the same unless you've changed how many visits are input to the custom coadd.
#
# > E.g., `coadd_index = 6`

# %%
coadd_index = 8 # 6

# %% [markdown]
# Option to display information using the `inputs` and `outputs` methods for quanta.

# %%
# quanta[coadd_index].inputs

# %%
# quanta[coadd_index].outputs

# %%
for output in quanta[coadd_index].outputs:
    print(output)
# Out:
# DatasetType('assembleCoadd_log', {band, skymap, tract, patch}, ButlerLogRecords)
# DatasetType('deepCoadd_inputMap', {band, skymap, tract, patch}, HealSparseMap)
# DatasetType('deepCoadd', {band, skymap, tract, patch}, ExposureF)
# DatasetType('assembleCoadd_metadata', {band, skymap, tract, patch}, PropertySet)

# %% [markdown]
# The deepCoadd is the output we're interested in. Notice that it has a DatasetType of ExposureF, so it is the image.

# %%
quanta[coadd_index].outputs['deepCoadd']
# Out:
# [DatasetRef(DatasetType('deepCoadd', {band, skymap, tract, patch}, ExposureF), {band: 'i', skymap: 'DC2', tract: 4431, patch: 17})]

# %% [markdown]
# From the square brackets, it's a list of just one element. So the DatasetRef for just our new coadd would be:
#
# > `quanta[coadd_index].outputs['deepCoadd'][0]`
#
# The above output is used in Section 4.2.1, below, to retrieve the new custom coadd image from the simpleButler.

# %% [markdown]
# ### 4.2. The new Coadd
#
# #### 4.2.1. Option 1 - use the quanta

# %%
#my_new_deepCoadd = simpleButler.get(quanta[coadd_index].outputs['deepCoadd'][0])

# %% [markdown]
# #### 4.2.2. Option 2 - use the dataId
#
# The dataId for the deepCoadd of interest was already defined:
# > `my_dataId = {'band': 'i', 'tract': my_tract, 'patch': my_patch}`
#
# Use it to retrieve the newly made Coadd (which is named deepCoadd by default) from the simple butler.
#
# So long as you use the simpleButler, it will search the collections in order, and since we made sure that the new collection we just created and wrote to appears first -- as checked in the first cell below -- it will take the deepCoadd from that new collection.

# %%
simpleButler.registry.getCollectionChain(my_outputCollection)
# Out:
# CollectionSearch(('u/alrakomala/coadd_recreation_nb/airmassTestWindow1', '2.2i/runs/DP0.2'))

# %%
my_new_deepCoadd = simpleButler.get('deepCoadd', dataId=my_dataId)

# %% [markdown]
# <br>
#
# **A note on accessing your run results in another notebook.**
#
# The results have been permanently written to the butler.
#
# If you instantiated a new butler in a new notebook: <br>
# `config = "dp02"`<br>
# `collection = "u/melissagraham/coadd_recreation_nb/TestWindow1"`<br>
# `butler = Butler(config, collections=collection)`<br>
#
# Then you would be able to define the dataId in the same way:<br>
# `my_dataId = {'band': 'i', 'tract': 4431, 'patch': 17}`<br>
#
# And retrieve your new deepCoadd with:<br>
# `my_new_deepCoadd = Butler.get('deepCoadd', dataId=my_dataId)`.
#
# In the two code cells above, since we already have our collection in the `simpleButler`, we use it, but it's not the only way.

# %% [markdown]
# #### 4.2.3. Check the inputs of the new Coadd
#
# Check the inputs of my_new_deepCoadd, and compare them with the "queryString", and see that they match.

# %%
my_new_deepCoadd_inputs = simpleButler.get("deepCoadd.coaddInputs", my_dataId)

# %%
#my_new_deepCoadd_inputs.visits.asAstropy()

# %%
fig = plt.figure(figsize=(12, 8))
afw_display = afwDisplay.Display(1)
afw_display.scale('asinh', 'zscale')
afw_display.mtv(my_new_deepCoadd.image)
plt.gca().axis('off')
# Out:
# (11899.5, 16099.5, 7899.5, 12099.5)

# %% [markdown]
# #### 4.2.4. Display the new Coadd

# %%
config1 = 'dp02'
collection1 = '2.2i/runs/DP0.2'
butler1 = Butler(config1, collections=collection1)
my_dataId1 = {'band': 'i', 'tract': 4431, 'patch': 17}

config2 = "dp02"
collection2 = "u/alrakomala/coadd_recreation_nb/airmassTestWindow1"
butler2 = Butler(config2, collections=collection2)
my_dataId2 = {'band': 'i', 'tract': 4431, 'patch': 17}

allVisits_deepCoadd = butler1.get('deepCoadd', dataId=my_dataId1)
bestAirmass_deepCoadd = butler2.get('deepCoadd', dataId=my_dataId2)


fig, ax = plt.subplots(1, 2, figsize=(12, 5))
plt.sca(ax[0])  
display1 = afwDisplay.Display(frame=fig) 
display1.scale('asinh', min=-0.3, max=0.5)
#display1.scale('asinh', 'zscale')
display1.mtv(allVisits_deepCoadd.image)
display1.show_colorbar(False)
ax[0].axis('off')

plt.sca(ax[1])
display2 = afwDisplay.Display(frame=fig)
display2.scale('asinh', min=-0.3, max=0.5)
display2.mtv(bestAirmass_deepCoadd.image)
display2.show_colorbar(False)
ax[1].axis('off')
plt.tight_layout()
plt.show()
